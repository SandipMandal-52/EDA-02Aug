# %% [markdown]
# **May 28**

# %%
# import the packages
# read the data 
# select the dtypes
# create a frequency table for continents column using values counts
# save in local

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
visa_df= pd.read_csv(r"D:\Data Science\Class Recordings\datasets\Visadataset.csv",
           sep=',')

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
cat = visa_df.select_dtypes(include='object').columns
num = visa_df.select_dtypes(exclude='object').columns

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
df = pd.DataFrame(zip(keys,values))
df.to_csv('continent_df.csv',index = False)

# %%
visa_df['case_id'].nunique()
# Out:
# 25480

# %%
len(cat)
# Out:
# 9

# %%
for i in cat[1:]:
    print(i)
# Out:
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status

# %%
keys = visa_df[i].value_counts().keys()
values = visa_df[i].value_counts().values
df = pd.DataFrame(zip(keys,values))
df.to_csv('continent_df.csv',index = False)

# %%
df
# Out:
#            0      1
# 0  Certified  17018
# 1     Denied   8462

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns=['Class','Frequency'])
    df.to_csv(f'{i}_df.csv',index = False)

# %%
# I want to save all the frequency table in another forlder
# Create a folder at same python location directory

# provide the full path while saving

# %%
import os
folder_name = 'frequency_table'
directory = os.getcwd()
for i in cat[1:]:
    file_name = f'{i}.csv'
    # directoryh + '\\'+ folder_name
    path = os.path.join(directory,folder_name,file_name)

# %%
import os
folder_name = 'frequency_table'
directory = os.getcwd()
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns=['Class','Frequency'])
    file_name = f'{i}.csv'
    path = os.path.join(directory,folder_name,file_name)
    df.to_csv(path,index=False)
    #df.to_csv(f'{i}_df.csv',index = False)

# %% [markdown]
# **Make directory**

# %%
import os
folder_name = 'freque_table'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
directory = os.getcwd()
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),
                     columns=['Class','Frequency'])
    file_name = f'{i}.csv'
    path = os.path.join(directory,folder_name,file_name)
    df.to_csv(path,index=False)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'freque_table'

# %%
keys = visa_df['continent'].value_counts().keys()      # lables
values = visa_df['continent'].value_counts().values        # values
plt.bar(keys,values)
plt.savefig('Continent_bar.jpg')

# %%
keys = visa_df['continent'].value_counts().keys()      # lables
values = visa_df['continent'].value_counts().values        # values
plt.pie(values,
        labels = keys,
        autopct='%0.2f%%',
        startangle = 90,
         explode = [0.1,0.2,0.2,0.3,0.4,0.5]
       )
plt.show()

# %%
import os
folder_name = 'bar_charts'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
directory = os.getcwd()
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.bar(keys,values)
    df = pd.DataFrame(zip(keys,values),
                     columns=['Class','Frequency'])
    file_name = f'{i}.jpg'
    plt.bar(keys,values)
    plt.savefig('Continent_bar.jpg')
    path = os.path.join(directory,folder_name,file_name)
    #df.to_csv(path,index=False)
    plt.savefig(path)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'bar_charts'

# %% [markdown]
# ## for Pie chart

# %%
import os
folder_name = 'Pie_chart'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
directory = os.getcwd()
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.pie(keys,values)
    # df = pd.DataFrame(zip(keys,values),
    #                  columns=['Class','Frequency'])
    file_name = f'{i}.jpg'
    #plt.pie(keys,values)
    #plt.savefig('Continent_bar.jpg')
    path = os.path.join(directory,folder_name,file_name)
    #df.to_csv(path,index=False)
    plt.savefig(path)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'Pie_chart'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 11
#       9 keys = visa_df[i].value_counts().keys()
#      10 values = visa_df[i].value_counts().values
# ---> 11 plt.pie(keys,values)
#      12 # df = pd.DataFrame(zip(keys,values),
#      13 #                  columns=['Class','Frequency'])
#      14 file_name = f'{i}.jpg'
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
# ...

# %%
import os
folder_name = 'Pie_chart'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
directory = os.getcwd()
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    plt.pie(keys,values)
    file_name = f'{i}.jpg'
    path = os.path.join(directory,folder_name,file_name)
    plt.savefig(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 11
#       9 keys = visa_df[i].value_counts().keys()
#      10 values = visa_df[i].value_counts().values
# ---> 11 plt.pie(keys,values)
#      12 file_name = f'{i}.jpg'
#      13 path = os.path.join(directory,folder_name,file_name)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
# ...

# %%
visa_df = pd.read_csv(r"D:\Data Science\Class Recordings\Datasets\Visadataset.csv")

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **Subplots**

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
# how many columns 0-1  = 8
# possible combination  2x4    4x2    1x8    8x1    3x3  

plt.subplot(4,2,1)
plt.subplot(4,2,2)
plt.subplot(4,2,3)
plt.subplot(4,2,4)
# Out:
# <Axes: >

# %%
n = len(cat)
for i in range(1,n):
    plt.subplot(3,3,i)
    keys = visa_df['continent'].value_counts().keys()
    values = visa_df['continent'].value_counts().values
    plt.bar(keys,values)

# %%
n = len(cat)
plt.figure(figsize=(24,10))
for i in range(1,n):
    plt.subplot(3,3,i)
    col = cat[i]    # cat [1]   'continent'
    keys = visa_df[col].value_counts().keys()
    values = visa_df[col].value_counts().values

    bars = plt.bar(keys,values, color = plt.cm.set2.color)       # using a colormap for colkr
    plt.title(f'Distribution {bars}
    plt.bar(keys,values)
)

# i will do coloring and naming after some time
